# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# Matplot library in a visulization tool to plot the 2D Arrays. It is greatly helpful to represent a large amount of data in a simple graph like format.
# Matplotlib consists of several plots like line, bar, scatter, histogram ,plot and etc.

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.
#
# import numpy as np<br>
# np.random.seed(3)<br>
# x = 3 + np.random.normal(0, 2, 50)<br>
# y = 3 + np.random.normal(0, 2, len(x))<br>
# Note: Also add title, xlabel, and ylabel to the plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.figure(figsize=[5,3])
plt.scatter(x,y)
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title('X vs Y')
# Out:
# Text(0.5, 1.0, 'X vs Y')

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# #### subplot() function is used to create multiples axes in a single figure. It allows us to plot as many graph as required.

# %%
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

fig =plt.figure(figsize=[12,6])
ax = fig.subplots(nrows=2,ncols=2)

ax[0,0].plot(x1,y1)
ax[0,0].set_title('Plot 1')
ax[0,1].plot(x2,y2)
ax[0,1].set_title('Plot 2')
ax[1,0].plot(x3,y3)
ax[1,0].set_title('Plot 3')
ax[1,1].plot(x4,y4)
ax[1,1].set_title('Plot 4')
# Out:
# Text(0.5, 1.0, 'Plot 4')

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.<br>
# import numpy as np<br>
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])<br>
# profit = np.array([3000, 8000, 1000, 10000])<br>

# %% [markdown]
# #### Bar Plot is a type of graph in which the data is represented in vertical or horizontal bars. It plots the categorical vs Numerical data.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

fig =plt.figure(figsize=[15,6])
ax = fig.subplots(nrows=1,ncols=2)

ax[0].bar(company,profit)
ax[0].set_xlabel('Companies')
ax[0].set_ylabel('Profit')

ax[1].barh(company,profit)
ax[1].set_xlabel('Companies')
ax[1].set_ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
#
# box1 = np.random.normal(100, 10, 200)<br>
# box2 = np.random.normal(90, 20, 200)<br>

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

fig =plt.figure(figsize=[15,6])
ax = fig.subplots(nrows=1,ncols=2)

ax[0].boxplot(box1)
ax[1].boxplot(box2)

plt.show()
